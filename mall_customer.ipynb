# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import mysql.connector
from tabulate import tabulate

# %%
df = pd.read_csv(r"C:\Users\krupa\OneDrive\Desktop\practice\dataset\Mall_Customers.csv", sep=",", header=0)
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.dtypes
# Out:
# CustomerID                 int64
# Genre                     object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
conn = mysql.connector.connect(host='localhost', username='root', password='mysql', db='customer')
cursor = conn.cursor()
cursor.execute("SELECT * FROM customer.mall_customers")
result = cursor.fetchall()
print(tabulate(result, headers=df.columns, tablefmt="grid"))
# Out:
# +--------------+---------+-------+----------------------+--------------------------+
# |   CustomerID | Genre   |   Age |   Annual Income (k$) |   Spending Score (1-100) |
# +==============+=========+=======+======================+==========================+
# |         0001 | Male    |    19 |                   15 |                       39 |
# +--------------+---------+-------+----------------------+--------------------------+
# |         0002 | Male    |    21 |                   15 |                       81 |
# +--------------+---------+-------+----------------------+--------------------------+
# |         0003 | Female  |    20 |                   16 |                        6 |
# +--------------+---------+-------+----------------------+--------------------------+
# |         0004 | Female  |    23 |                   16 |                       77 |
# +--------------+---------+-------+----------------------+--------------------------+
# ...

# %%
x
